# %%
import pandas as pd
import requests
import bs4
import numpy as np
import re

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Nobel_laureates'

# %%
response =requests.get(url)
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
html=response.content

# %%
html
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of Nobel laureates - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"cabb56c7-3346-4863-b74b-03ed8d0819f4","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Nobel_laureates","wgTitle":"List of Nobel laureates","wgCurRevisionId":1054557069,"wgRevisionId":1054557069,"wgArticleId":1175987,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely semi-prote
# ...

# %%
type(html) #son 0 y 1
# Out:
# bytes

# %%
#ahora hacemos la sopa; html pone la información en tags; 'html.parser dos argumentos '
sopa=bs4.BeautifulSoup(html, 'html.parser')

type(sopa)  #atributos y métodos
# Out:
# bs4.BeautifulSoup

# %%
sopa
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Nobel laureates - Wikipedia</title>
# ...

# %%
#para sacar todas las etiquetas
parsed_tags = set([tag.name for tag in sopa.find_all(True)])
parsed_tags
# Out:
# {'a',
#  'abbr',
#  'b',
#  'body',
#  'br',
#  'cite',
#  'div',
#  'dl',
#  'dt',
#  'footer',
#  'form',
#  'h1',
#  'h2',
#  'h3',
#  'head',
#  'html',
#  'i',
#  'img',
#  'input',
#  'label',
#  'li',
#  'link',
#  'meta',
#  'nav',
#  'noscript',
#  'ol',
#  'p',
#  'q',
#  'script',
#  'small',
#  'span',
#  'style',
#  'sup',
#  'table',
#  'tbody',
#  'td',
#  'th',
#  'title',
#  'tr',
#  'ul'}

# %%
tables= sopa.find_all('table')
tables
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th>Year
#  </th>
#  <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physics" title="List of Nobel laureates in Physics">Physics</a>
#  </th>
#  <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Chemistry" title="List of Nobel laureates in Chemistry">Chemistry</a>
#  </th>
#  <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine" title="List of Nobel laureates in Physiology or Medicine">Physiology<br/>or Medicine</a>
#  </th>
#  <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Literature" title="List of Nobel laureates in Literature">Literature</a>
#  </th>
#  <th width="16%"><a href="/wiki/List_of_Nobel_Peace_Prize_laureates" title="List of Nobel Peace Prize laureates">Peace</a>
#  </th>
# ...

# %%
print(len(tables))
print(type(tables))
# Out:
# 6
# <class 'bs4.element.ResultSet'>

# %%
element = tables[0]
element
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Year
# </th>
# <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physics" title="List of Nobel laureates in Physics">Physics</a>
# </th>
# <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Chemistry" title="List of Nobel laureates in Chemistry">Chemistry</a>
# </th>
# <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine" title="List of Nobel laureates in Physiology or Medicine">Physiology<br/>or Medicine</a>
# </th>
# <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Literature" title="List of Nobel laureates in Literature">Literature</a>
# </th>
# <th width="16%"><a href="/wiki/List_of_Nobel_Peace_Prize_laureates" title="List of Nobel Peace Prize laureates">Peace</a>
# </th>
# ...

# %%
type(element)
# Out:
# bs4.element.Tag

# %%
sopa.attrs
# Out:
# {}

# %%
element.attrs
# Out:
# {'class': ['wikitable', 'sortable']}

# %%
table = sopa.find_all('table', {'class':'wikitable'})
table
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th>Year
#  </th>
#  <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physics" title="List of Nobel laureates in Physics">Physics</a>
#  </th>
#  <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Chemistry" title="List of Nobel laureates in Chemistry">Chemistry</a>
#  </th>
#  <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine" title="List of Nobel laureates in Physiology or Medicine">Physiology<br/>or Medicine</a>
#  </th>
#  <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Literature" title="List of Nobel laureates in Literature">Literature</a>
#  </th>
#  <th width="16%"><a href="/wiki/List_of_Nobel_Peace_Prize_laureates" title="List of Nobel Peace Prize laureates">Peace</a>
#  </th>
# ...

# %%
len(table)
# Out:
# 1

# %%
nobels =  table[0]
type(nobels)
# Out:
# bs4.element.Tag

# %%
nobels.name
# Out:
# 'table'

# %%
set([tag.name for tag in nobels.find_all(True)])
#para sacar los tags únicos hay que hacerlos set.
# Out:
# {'a', 'br', 'i', 'span', 'sup', 'tbody', 'td', 'th', 'tr'}

# %%
first_row = nobels.find_all('th')
print(first_row)
print(len(first_row))
# Out:
# [<th>Year
# </th>, <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physics" title="List of Nobel laureates in Physics">Physics</a>
# </th>, <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Chemistry" title="List of Nobel laureates in Chemistry">Chemistry</a>
# </th>, <th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine" title="List of Nobel laureates in Physiology or Medicine">Physiology<br/>or Medicine</a>
# </th>, <th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Literature" title="List of Nobel laureates in Literature">Literature</a>
# </th>, <th width="16%"><a href="/wiki/List_of_Nobel_Peace_Prize_laureates" title="List of Nobel Peace Prize laureates">Peace</a>
# ...

# %%
titulo= first_row[0].text
titulo
# Out:
# 'Year\n'

# %%
titulos = []
for t in first_row:
    titulos.append(t.text)
titulos
# Out:
# ['Year\n',
#  'Physics\n',
#  'Chemistry\n',
#  'Physiologyor Medicine\n',
#  'Literature\n',
#  'Peace\n',
#  'Economics(The Sveriges Riksbank Prize)[13][a]\n',
#  'Year\n',
#  'Physics\n',
#  'Chemistry\n',
#  'Physiologyor Medicine\n',
#  'Literature\n',
#  'Peace\n',
#  'Economics\n']

# %%
desired_titles =[]
for t in range(int(len(first_row)/2)):
    desired_titles.append(first_row[t].text.split('\n')[0].split('[')[0])
desired_titles
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiologyor Medicine',
#  'Literature',
#  'Peace',
#  'Economics(The Sveriges Riksbank Prize)']

# %%
desired_titles =[]
for t in range(int(len(first_row)/2)):
    desired_titles.append(first_row[t].text)
desired_titles
# Out:
# ['Year\n',
#  'Physics\n',
#  'Chemistry\n',
#  'Physiologyor Medicine\n',
#  'Literature\n',
#  'Peace\n',
#  'Economics(The Sveriges Riksbank Prize)[13][a]\n']

# %%
desired_titles =[]
for t in range(int(len(first_row)/2)):
    desired_titles.append(first_row[t].text.replace('\n','').split('[')[0])
desired_titles
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiologyor Medicine',
#  'Literature',
#  'Peace',
#  'Economics(The Sveriges Riksbank Prize)']

# %%
x=len(desired_titles)
int(x)
type(x)
# Out:
# int

# %%
rows=nobels.find_all('tr')
len(rows)
# Out:
# 123

# %%
row =rows[1]
row
# Out:
# <tr>
# <td align="center">1901
# </td>
# <td><span data-sort-value="Röntgen, Wilhelm"><span class="vcard"><span class="fn"><a href="/wiki/Wilhelm_R%C3%B6ntgen" title="Wilhelm Röntgen">Wilhelm Röntgen</a></span></span></span>
# </td>
# <td><span data-sort-value="Hoff, Jacobus Henricus van 't"><span class="vcard"><span class="fn"><a href="/wiki/Jacobus_Henricus_van_%27t_Hoff" title="Jacobus Henricus van 't Hoff">Jacobus Henricus van 't Hoff</a></span></span></span>
# </td>
# <td><span data-sort-value="von Behring, Emil Adolf"><span class="vcard"><span class="fn"><a class="mw-redirect" href="/wiki/Emil_Adolf_von_Behring" title="Emil Adolf von Behring">Emil Adolf von Behring</a></span></span></span>
# </td>
# <td><span data-sort-value="Prudhomme, Sully"><span class="vcard"><span class="fn"><a href="/wiki/Sully_Prudhomme" title="Sully Prudhomme">Sully Prudhomme</a></span></span></span>
# </td>
# ...

# %%
datos=[i.text.replace('\n','') for row in rows for i in row][1::2]
datos
# Out:
# ['Year',
#  'Physics',
#  'Chemistry',
#  'Physiologyor Medicine',
#  'Literature',
#  'Peace',
#  'Economics(The Sveriges Riksbank Prize)[13][a]',
#  '1901',
#  'Wilhelm Röntgen',
#  "Jacobus Henricus van 't Hoff",
#  'Emil Adolf von Behring',
#  'Sully Prudhomme',
#  'Henry Dunant;Frédéric Passy',
#  '—',
#  '1902',
#  'Hendrik Lorentz;Pieter Zeeman',
#  'Hermann Emil Fischer',
#  'Ronald Ross',
#  'Theodor Mommsen',
#  'Élie Ducommun;Charles Albert Gobat',
#  '—',
#  '1903',
#  'Henri Becquerel;Pierre Curie;Marie Curie',
#  'Svante Arrhenius',
#  'Niels Ryberg Finsen',
#  'Bjørnstjerne Bjørnson',
#  'Randal Cremer',
#  '—',
#  '1904',
#  'Lord Rayleigh',
#  'William Ramsay',
#  'Ivan Pavlov',
#  'Frédéric Mistral;José Echegaray',
#  'Institut de Droit International',
#  '—',
#  '1905',
#  'Philipp Lenard',
#  'Adolf von Baeyer',
#  'Robert Koch',
#  'Henryk Sienkiewicz',
#  'Bertha von Suttner',
#  '—',
#  '1906',
#  'J. J. Thomson',
#  'Henri Moissan',
# ...

# %%
y=len(datos)
int(y)
# Out:
# 847

# %%
shape=y/x
int(shape)
shape=int(shape)
type(shape)
# Out:
# int

# %%
len(rows)
# Out:
# 123

# %%
df = pd.DataFrame(datos)
df
# Out:
#                          0
# 0                     Year
# 1                  Physics
# 2                Chemistry
# 3    Physiologyor Medicine
# 4               Literature
# ..                     ...
# 842              Chemistry
# 843  Physiologyor Medicine
# 844             Literature
# 845                  Peace
# 846              Economics
#
# [847 rows x 1 columns]

# %%
#Ahora necesitamos crear bien el dataframe
array= np.array(datos)
array=array.reshape(shape,x)
array
# Out:
# array([['Year', 'Physics', 'Chemistry', 'Physiologyor Medicine',
#         'Literature', 'Peace',
#         'Economics(The Sveriges Riksbank Prize)[13][a]'],
#        ['1901', 'Wilhelm Röntgen', "Jacobus Henricus van 't Hoff",
#         'Emil Adolf von Behring', 'Sully Prudhomme',
#         'Henry Dunant;Frédéric Passy', '—'],
#        ['1902', 'Hendrik Lorentz;Pieter Zeeman', 'Hermann Emil Fischer',
#         'Ronald Ross', 'Theodor Mommsen',
#         'Élie Ducommun;Charles Albert Gobat', '—'],
#        ['1903', 'Henri Becquerel;Pierre Curie;Marie Curie',
#         'Svante Arrhenius', 'Niels Ryberg Finsen',
#         'Bjørnstjerne Bjørnson', 'Randal Cremer', '—'],
#        ['1904', 'Lord Rayleigh', 'William Ramsay', 'Ivan Pavlov',
#         'Frédéric Mistral;José Echegaray',
#         'Institut de Droit International', '—'],
#        ['1905', 'Philipp Lenard', 'Adolf von Baeyer', 'Robert Koch',
#         'Henryk Sienkiewicz', 'Bertha von Suttner', '—'],
# ...

# %%
df=pd.DataFrame(array,columns=desired_titles).drop([0])
df
# Out:
#      Year                                           Physics  \
# 1    1901                                   Wilhelm Röntgen
# 2    1902                     Hendrik Lorentz;Pieter Zeeman
# 3    1903          Henri Becquerel;Pierre Curie;Marie Curie
# 4    1904                                     Lord Rayleigh
# 5    1905                                    Philipp Lenard
# ..    ...                                               ...
# 116  2018      Arthur Ashkin;Gérard Mourou;Donna Strickland
# 117  2019        James Peebles; Michel Mayor; Didier Queloz
# 118  2020    Roger Penrose; Reinhard Genzel; Andrea M. Ghez
# 119  2021  Syukuro Manabe; Klaus Hasselmann; Giorgio Parisi
# 120  Year                                           Physics
#
#                                              Chemistry  \
# 1                         Jacobus Henricus van 't Hoff
# 2                                 Hermann Emil Fischer
# 3                                     Svante Arrhenius
# ...

# %%
df.to_csv('wikitable.csv')
